# %%
import pandas as pd #data manipulation
import numpy as np
import matplotlib.pyplot as plt #plotting graphs
import seaborn as sns #plotting graphs

import statsmodels.api as sm
import statsmodels.formula.api as smf #regression

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('twitter-stocks.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2259 entries, 0 to 2258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2259 non-null   object
#  1   Open       2259 non-null   float64
#  2   High       2259 non-null   float64
#  3   Low        2259 non-null   float64
#  4   Close      2259 non-null   float64
#  5   Adj Close  2259 non-null   float64
#  6   Volume     2259 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 123.7+ KB
#               Open         High          Low        Close    Adj Close  \
# count  2259.000000  2259.000000  2259.000000  2259.000000  2259.000000
# mean     36.020286    36.699881    35.339465    36.003625    36.003625
# std      14.118463    14.372057    13.828724    14.089989    14.089989
# min      13.950000    14.220000    13.725000    14.010000    14.010000
# 25%      25.550000    26.215001    24.912501    25.410000    25.410000
# ...

# %%
#converting the date from an object to datetime
df['Date'] = pd.to_datetime(df['Date'])

#organising by date (oldest first)
df = df.sort_values('Date').reset_index(drop=True)

#creating daily return (% change in closing price)
df['Daily_Return'] = df['Close'].pct_change() * 100

#creating volatility (absolute daily return)
df['Volatility'] = df['Daily_Return'].abs()

#creating next-day volatility
df['Next_Day_Volatility'] = df['Volatility'].shift(-1)

#createing a 20 day moving average
df['MA20'] = df['Close'].rolling(window=20).mean()

#flagging the Musk era (from January 2022 onwards)
df['Musk_Era'] = (df['Date'].dt.year == 2022).astype(int)

#drops the last row, as it will have NaN for next day volatility
df = df.dropna()

df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 19 2013-12-05  43.450001  46.349998  42.830002  45.619999  45.619999
# 20 2013-12-06  45.750000  45.799999  44.540001  44.950001  44.950001
# 21 2013-12-09  45.590000  49.840000  45.020000  49.139999  49.139999
# 22 2013-12-10  48.900002  52.580002  48.700001  51.990002  51.990002
# 23 2013-12-11  52.400002  53.869999  51.000000  52.340000  52.340000
#
#         Volume  Daily_Return  Volatility  Next_Day_Volatility     MA20  \
# 19  11813520.0      4.417487    4.417487             1.468650  42.1395
# 20   6236232.0     -1.468650    1.468650             9.321464  42.1420
# 21  17366614.0      9.321464    9.321464             5.799762  42.5165
# 22  25792002.0      5.799762    5.799762             0.673203  42.9710
# 23  26631535.0      0.673203    0.673203             5.712652  43.4930
#
#     Musk_Era
# 19         0
# 20         0
# 21         0
# 22         0
# 23         0

# %%
df.info()
df.head(2250) #seeing if the Musk Era does indeed get flagged.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2239 entries, 19 to 2257
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2239 non-null   datetime64[ns]
#  1   Open                 2239 non-null   float64
#  2   High                 2239 non-null   float64
#  3   Low                  2239 non-null   float64
#  4   Close                2239 non-null   float64
#  5   Adj Close            2239 non-null   float64
#  6   Volume               2239 non-null   float64
#  7   Daily_Return         2239 non-null   float64
#  8   Volatility           2239 non-null   float64
#  9   Next_Day_Volatility  2239 non-null   float64
#  10  MA20                 2239 non-null   float64
#  11  Musk_Era             2239 non-null   int32
# dtypes: datetime64[ns](1), float64(10), int32(1)
# memory usage: 218.7 KB
#            Date       Open       High        Low      Close  Adj Close  \
# ...

# %%
# Plot 1 — Full price history 2013–2022
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Close'], color='royalblue', linewidth=1)
plt.plot(df['Date'], df['MA20'], color='orange', linewidth=1, linestyle='--', label='20-day MA')
plt.title('Twitter Stock Price History (2013–2022)', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.tight_layout()
plt.show()
